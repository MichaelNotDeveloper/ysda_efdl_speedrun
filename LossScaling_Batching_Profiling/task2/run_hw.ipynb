# %%
# %load_ext autoreload
# %autoreload 2

# %%
#!bash load_data.sh

# %%
import matplotlib.pyplot as plt
from dataset import *
from run_epoch import *

DATA_PATH = "./data/wikitext-103-raw-v1"

def plot_stats(stats):
    plt.plot(stats['deltas'])
    plt.axhline(y=stats['max'], label='max', c="red")
    plt.axhline(y=stats['min'], label='min', c="red")
    plt.axhline(y=stats['mean'], label='mean', c="green")
    plt.axhline(y=stats['median'], label='median', c="orange")
    plt.legend()
    plt.show()
# Out:
# /home/jupyter/.local/lib/python3.10/site-packages/transformers/utils/hub.py:124: FutureWarning: Using `TRANSFORMERS_CACHE` is deprecated and will be removed in v5 of Transformers. Use `HF_HOME` instead.
#   warnings.warn(

# %%
#stats_brain=run_epoch(DataMode.BRAIN)
#plot_stats(stats_brain)

# %%
stats_big_brain=run_epoch(DataMode.BIG_BRAIN)
plot_stats(stats_big_brain)
# Out:
# /home/jupyter/.local/lib/python3.10/site-packages/huggingface_hub/file_download.py:949: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# Loading data/wikitext-103-raw-v1/train-00000-of-00002.txt...
# Loading data/wikitext-103-raw-v1/train-00001-of-00002.txt...
# 100%|██████████| 18204/18204 [04:40<00:00, 64.79it/s]
